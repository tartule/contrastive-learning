# %%
#pip install tensorflow-addons

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
num_classes = 10
input_shape = (32, 32, 3)

AUTO=tf.data.AUTOTUNE
learning_rate = 0.001
batch_size = 128#256
hidden_units = 512
projection_units = 128
num_epochs = 50
dropout_rate = 0.5
temperature = 0.05



# Load the train and test data splits
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Display shapes of train and test datasets
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

test_dataset=(tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .shuffle(1024)
    .batch(batch_size)
    .prefetch(AUTO)
)
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.02),
        layers.RandomWidth(0.2),
        layers.RandomHeight(0.2),
    ]
)

# Setting the state of the normalization layer.
data_augmentation.layers[0].adapt(x_train)

# %%
def create_encoder(backbone=keras.applications.ResNet50V2(
        include_top=False, weights=None, input_shape=input_shape, pooling="avg"
    )):
    

    inputs = keras.Input(shape=input_shape)
    augmented = data_augmentation(inputs)
    outputs = backbone(augmented)
    model = keras.Model(inputs=inputs, outputs=outputs, name="cifar10-encoder")
    return model


encoder = create_encoder()
encoder.summary()
# Out:
# Model: "cifar10-encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  sequential (Sequential)     (None, 32, 32, 3)         7
#
#  resnet50v2 (Functional)     (None, 2048)              23564800
#
# =================================================================
# Total params: 23,564,807
# Trainable params: 23,519,360
# Non-trainable params: 45,447
# _________________________________________________________________

# %%
def create_classifier(encoder, trainable=True):

    for layer in encoder.layers:
        layer.trainable = trainable

    inputs = keras.Input(shape=input_shape)
    features = encoder(inputs)
    features = layers.Dropout(dropout_rate)(features)
    features = layers.Dense(hidden_units, activation="relu")(features)
    features = layers.Dropout(dropout_rate)(features)
    outputs = layers.Dense(num_classes, activation="softmax")(features)

    model = keras.Model(inputs=inputs, outputs=outputs, name="cifar10-classifier")
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(),
        metrics=[keras.metrics.SparseCategoricalAccuracy()],
    )
    return model

# %% [markdown]
# ## model definition with the api

# %%
def apply_resnet_block(x,downsample,conv_by_block):
    
    depth_input=x.shape[-1]
    
    
    if downsample:
        depth=depth_input*2
        skiped=layers.Conv2D(depth,1,strides=(2,2),activation=None)(x)#linear projection
        x=layers.Conv2D(depth,3,strides=(2,2), activation='relu',padding="same")(x)
        x=layers.BatchNormalization()(x)
    else:
        depth=depth_input
        skiped=x
        x=layers.Conv2D(depth,3, activation='relu',padding="same")(x)
        x=layers.BatchNormalization()(x)
        
    for i in range(1,conv_by_block-1):
        x=layers.Conv2D(depth,3, activation='relu',padding="same")(x)
        x=layers.BatchNormalization()(x)
    
    x=layers.Conv2D(depth,3,padding="same")(x)#don't apply activation to the last 
    x=skiped+x
    x=layers.ReLU()(x)
    x=layers.BatchNormalization()(x)
   
    return x

def get_resnet_backbone(input_shape,hparams):
    """
    """
    assert hparams["conv_by_block"]>=2
    inputs=layers.Input((32,32,3))
    x=layers.Conv2D(hparams["depth_first_convolution"],7,strides=(2,2),activation='relu',padding="same")(inputs)
    x=layers.BatchNormalization()(x)
    for block in range(1,hparams["number_of_block"]+1):
        x=apply_resnet_block(x,block in hparams["downsample_num"],hparams["conv_by_block"])
       
        
    x=layers.Conv2D(hparams["output_dim"],3, activation='relu',padding="same")(x)
    x=layers.BatchNormalization()(x)
    if hparams["globalPoolingType"]=="Mean":
        
        x=layers.GlobalAveragePooling2D()(x)
 
    return tf.keras.Model(inputs,x)



hparams_resnet={"depth_first_convolution":64,
                "output_dim":2048,
                "number_of_block":5,
                "downsample_num":[4,5],
                "conv_by_block":2,
                "globalPoolingType":"Mean"
            }




resnet=get_resnet_backbone(input_shape,hparams_resnet)

resnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 16, 16, 64)   9472        ['input_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 16, 16, 64)  0           ['batch_normalization[0][0]',
#  da)                                                              'conv2d_2[0][0]']
#
#  re_lu (ReLU)                   (None, 16, 16, 64)   0           ['tf.__operators__.add[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 64)  256         ['re_lu[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_3[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 16, 16, 64)  0           ['batch_normalization_2[0][0]',
#  mbda)                                                            'conv2d_4[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 16, 16, 64)   0           ['tf.__operators__.add_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 64)  256         ['re_lu_1[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   36928       ['batch_normalization_5[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 16, 16, 64)  0           ['batch_normalization_4[0][0]',
#  mbda)                                                            'conv2d_6[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 16, 16, 64)   0           ['tf.__operators__.add_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 64)  256         ['re_lu_2[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 128)    73856       ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 8, 128)   512         ['conv2d_8[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 128)    8320        ['batch_normalization_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 128)    147584      ['batch_normalization_7[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 8, 8, 128)   0           ['conv2d_7[0][0]',
#  mbda)                                                            'conv2d_9[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 8, 8, 128)    0           ['tf.__operators__.add_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 128)   512         ['re_lu_3[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 256)    295168      ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 4, 4, 256)   1024        ['conv2d_11[0][0]']
#  rmalization)
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 256)    33024       ['batch_normalization_8[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 256)    590080      ['batch_normalization_9[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 4, 4, 256)   0           ['conv2d_10[0][0]',
#  mbda)                                                            'conv2d_12[0][0]']
#
#  re_lu_4 (ReLU)                 (None, 4, 4, 256)    0           ['tf.__operators__.add_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 256)   1024        ['re_lu_4[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 4, 4, 2048)   4720640     ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 2048)  8192        ['conv2d_13[0][0]']
#  ormalization)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['batch_normalization_11[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 6,112,768
# Trainable params: 6,106,240
# Non-trainable params: 6,528
# __________________________________________________________________________________________________

# %%
import time as time

class SupervisedContrastiveLoss(keras.losses.Loss):
    def __init__(self, temperature=1, name=None):
        super(SupervisedContrastiveLoss, self).__init__(reduction=tf.keras.losses.Reduction.NONE,name=name)
        self.temperature = temperature

    def __call__(self, y_true, feature_vectors,sample_weight=None):
        #adapted from https://github.com/HobbitLong/SupContrast/blob/master/losses.py
        #only change should be the change of computation of the maximum for the numerical stability trick
        
        feature_vectors1,feature_vectors2=feature_vectors[0],feature_vectors[1]
        
        #feature vectors1_2 : shape (batch_size,_)
        feature_vectors=tf.concat([feature_vectors1,feature_vectors2],axis=0)
        # Normalize feature vectors
        feature_vectors_normalized = tf.math.l2_normalize(feature_vectors, axis=1)
        # Compute logits
        logits = tf.divide(
            tf.matmul(
                feature_vectors_normalized, tf.transpose(feature_vectors_normalized)
            ),
            self.temperature,
        )
        
        
        #y_pred = tf.convert_to_tensor(logits)
        #print(y_pred.shape)
        y_true = tf.cast(y_true, logits.dtype)

        # Expand to [2*batch_size, 1]
        y_true=tf.concat([y_true,y_true],axis=0)
        #y_true = tf.expand_dims(y_true, -1)#depend on the input shape of the labels
        
        is_similar = tf.cast(tf.equal(y_true, tf.transpose(y_true)), logits.dtype)
        
        #mask for self_contrasting terms
        bsz=is_similar.shape[0]
        t=time.time()
        
       
        indices=[[i,i] for i in range(bsz)]#
        update=[0 for i in range(bsz)]
        mask_logits=tf.ones_like(logits)
        mask_logits=tf.linalg.set_diag(mask_logits,)
        mask_logits=tf.tensor_scatter_nd_update(mask_logits,indices,update)
        
        #for numerical stability 

        max_logits=tf.math.reduce_max(mask_logits*logits,axis=1,keepdims=True)#take the max possible value for the logits
        logits=logits-tf.stop_gradient(max_logits)
        is_similar=is_similar*mask_logits
        
        log_softmax=logits-tf.math.log(tf.reduce_sum(mask_logits*tf.math.exp(logits),axis=1,keepdims=True))
        
        loss=tf.reduce_sum(is_similar*log_softmax,axis=1)/tf.reduce_sum(is_similar,axis=1)#compute the mean of the log likelhood
        
        return -tf.math.reduce_mean(loss)
                

def add_projection_heads(encoder):
    inputs = keras.Input(shape=input_shape)
    features1 = encoder(inputs)
    features2 = encoder(inputs)
    outputs1 = layers.Dense(projection_units, activation="relu")(features1)
    outputs2 = layers.Dense(projection_units, activation="relu")(features2)
    model = keras.Model(
        inputs=inputs, outputs=tf.stack([outputs1,outputs2]), name="cifar-encoder_with_projection-head"
    )
    return model

# %%
early_stop_unsup=tf.keras.callbacks.EarlyStopping(
    monitor="loss", patience=3, restore_best_weights=True
)
learning_rate=0.001
resnet=get_resnet_backbone(input_shape,hparams_resnet)

encoder = create_encoder(resnet)

encoder_with_projection_head = add_projection_heads(encoder)
encoder_with_projection_head.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=SupervisedContrastiveLoss(temperature),
)

encoder_with_projection_head.summary()

history = encoder_with_projection_head.fit(
    x=x_train, y=y_train, batch_size=batch_size, epochs=25,callbacks=[early_stop_unsup]
)
# Out:
# Model: "cifar-encoder_with_projection-head"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  cifar10-encoder (Functional)   (None, 2048)         6112775     ['input_6[0][0]',
#                                                                   'input_6[0][0]']
#
#  dense (Dense)                  (None, 128)          262272      ['cifar10-encoder[0][0]']
#
#  dense_1 (Dense)                (None, 128)          262272      ['cifar10-encoder[1][0]']
#
#  tf.stack (TFOpLambda)          (2, None, 128)       0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 6,637,319
# Trainable params: 6,630,784
# Non-trainable params: 6,535
# __________________________________________________________________________________________________
# Epoch 1/25
# 391/391 [==============================] - 117s 249ms/step - loss: 5.7717
# Epoch 2/25
# 391/391 [==============================] - 67s 171ms/step - loss: 5.0436
# Epoch 3/25
# 391/391 [==============================] - 67s 171ms/step - loss: 4.8451
# Epoch 4/25
# 391/391 [==============================] - 67s 171ms/step - loss: 4.6580
# Epoch 5/25
# 391/391 [==============================] - 65s 167ms/step - loss: 4.5027
# Epoch 6/25
# 391/391 [==============================] - 66s 168ms/step - loss: 4.3865
# Epoch 7/25
# 391/391 [==============================] - 64s 165ms/step - loss: 4.2927
# Epoch 8/25
# 391/391 [==============================] - 68s 175ms/step - loss: 4.2120
# Epoch 9/25
# 391/391 [==============================] - 67s 171ms/step - loss: 4.1346
# Epoch 10/25
# 391/391 [==============================] - 67s 172ms/step - loss: 4.0719
# Epoch 11/25
# 391/391 [==============================] - 66s 170ms/step - loss: 4.0435
# Epoch 12/25
# 391/391 [==============================] - 65s 167ms/step - loss: 3.9684
# Epoch 13/25
# 391/391 [==============================] - 65s 166ms/step - loss: 3.9212
# Epoch 14/25
# 391/391 [==============================] - 67s 172ms/step - loss: 3.8775
# Epoch 15/25
# 391/391 [==============================] - 65s 167ms/step - loss: 3.8403
# Epoch 16/25
# 391/391 [==============================] - 64s 165ms/step - loss: 3.8068
# Epoch 17/25
# 391/391 [==============================] - 64s 165ms/step - loss: 3.7700
# Epoch 18/25
# 391/391 [==============================] - 64s 165ms/step - loss: 3.7489
# Epoch 19/25
# 391/391 [==============================] - 65s 167ms/step - loss: 3.7141
# Epoch 20/25
# 391/391 [==============================] - 65s 166ms/step - loss: 3.6891
# Epoch 21/25
# 391/391 [==============================] - 68s 173ms/step - loss: 3.6595
# Epoch 22/25
# 391/391 [==============================] - 66s 169ms/step - loss: 3.6338
# Epoch 23/25
# 391/391 [==============================] - 66s 168ms/step - loss: 3.6072
# Epoch 24/25
# 391/391 [==============================] - 66s 168ms/step - loss: 3.5877
# Epoch 25/25
# 391/391 [==============================] - 66s 168ms/step - loss: 3.5712

# %%
early_stop=tf.keras.callbacks.EarlyStopping(
    monitor="sparse_categorical_accuracy", patience=3, restore_best_weights=True
)


classifier = create_classifier(encoder, trainable=False)


history = classifier.fit(x=x_train, y=y_train,validation_data=test_dataset, batch_size=batch_size, epochs=num_epochs,callbacks=[early_stop])

accuracy = classifier.evaluate(x_test, y_test)[1]
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
# Out:
# Epoch 1/50
# 391/391 [==============================] - 19s 40ms/step - loss: 0.2698 - sparse_categorical_accuracy: 0.9141 - val_loss: 0.5037 - val_sparse_categorical_accuracy: 0.8659
# Epoch 2/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.2091 - sparse_categorical_accuracy: 0.9308 - val_loss: 0.4918 - val_sparse_categorical_accuracy: 0.8649
# Epoch 3/50
# 391/391 [==============================] - 15s 40ms/step - loss: 0.1988 - sparse_categorical_accuracy: 0.9342 - val_loss: 0.4973 - val_sparse_categorical_accuracy: 0.8630
# Epoch 4/50
# 391/391 [==============================] - 14s 37ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9365 - val_loss: 0.4920 - val_sparse_categorical_accuracy: 0.8656
# Epoch 5/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1863 - sparse_categorical_accuracy: 0.9364 - val_loss: 0.4788 - val_sparse_categorical_accuracy: 0.8667
# Epoch 6/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1872 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.4575 - val_sparse_categorical_accuracy: 0.8696
# Epoch 7/50
# 391/391 [==============================] - 16s 41ms/step - loss: 0.1796 - sparse_categorical_accuracy: 0.9387 - val_loss: 0.4731 - val_sparse_categorical_accuracy: 0.8686
# Epoch 8/50
# 391/391 [==============================] - 16s 41ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.4743 - val_sparse_categorical_accuracy: 0.8699
# Epoch 9/50
# 391/391 [==============================] - 15s 38ms/step - loss: 0.1829 - sparse_categorical_accuracy: 0.9385 - val_loss: 0.4848 - val_sparse_categorical_accuracy: 0.8667
# Epoch 10/50
# 391/391 [==============================] - 17s 42ms/step - loss: 0.1720 - sparse_categorical_accuracy: 0.9409 - val_loss: 0.4934 - val_sparse_categorical_accuracy: 0.8651
# Epoch 11/50
# 391/391 [==============================] - 17s 43ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9391 - val_loss: 0.4887 - val_sparse_categorical_accuracy: 0.8678
# Epoch 12/50
# 391/391 [==============================] - 15s 39ms/step - loss: 0.1809 - sparse_categorical_accuracy: 0.9374 - val_loss: 0.5022 - val_sparse_categorical_accuracy: 0.8651
# Epoch 13/50
# 391/391 [==============================] - 16s 41ms/step - loss: 0.1761 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.4882 - val_sparse_categorical_accuracy: 0.8693
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4934 - sparse_categorical_accuracy: 0.8651
# Test accuracy: 86.51%
